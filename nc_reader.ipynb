# %%
import xarray as xr

# %% [markdown]
# ## here, the VV (?) data for the whole month of Jan (=20timestamps) is contained for 1000001 locations (=pixels)

# %%
ds = xr.open_dataset('output_jan.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 20, index: 100001)
# Coordinates:
#   * time     (time) datetime64[ns] 2020-01-03T05:09:36 ... 2020-01-30T16:42:13
# Dimensions without coordinates: index
# Data variables:
#     data     (index, time) float64 ...

# %% [markdown]
# ## thats how you get the sig0 vals. it doenst matter from where exactly they stem, as we will average the data anyhow

# %%
ds.data[1].values
# Out:
# array([-11.06,    nan, -15.16, -14.57,  -8.28,    nan, -10.88, -11.67,
#         -9.64,    nan, -13.42, -11.21,  -7.98,    nan, -14.32, -10.3 ,
#        -11.83,    nan, -13.86, -10.42])

# %%
import matplotlib.pyplot as plt
import scienceplots
import os

# plt.rcParams['axes.facecolor'] = 'white'
# plt.rcParams['axes.edgecolor'] = 'black'
# plt.rcParams['figure.facecolor'] = 'white'
# plt.rcParams['figure.edgecolor'] = 'black'
# plt.rcParams['xtick.color'] = 'black'
# plt.rcParams['ytick.color'] = 'black'
# plt.rcParams['axes.labelcolor'] = 'black'
# plt.rcParams['axes.titlecolor'] = 'black'
# plt.rcParams['savefig.edgecolor'] = 'black'
# plt.rcParams['savefig.facecolor'] = 'white'
# plt.rcParams['figure.figsize'] = [3, 2]

plt.style.use([
    os.path.join(
        'shared/120.030-2023W/groups/PracticalExGr_3/src/custom_style.mplstyle'
    ),
    'science',
    'ieee',
])

# %%
y = [
    -16.762967355222013, -16.41866966396978, -16.13195035670745,
    -16.190373510748536, -16.566545936900418, -16.478662708175197,
    -16.63036880488002, -16.675590388901703, -16.841032147332225,
    -16.768055113458967, -16.09159352250611, -16.0712047133094
]
x = [
    'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct',
    'Nov', 'Dec'
]

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot(x, y, marker='o', linestyle='dashed')
ax.set_xlabel('Time [month]')
ax.set_ylabel(r'$\sigma_{40}$ VH [dB]')
ax.xaxis.set_minor_locator(plt.NullLocator())
# ax.set_facecolor('xkcd:white')

plt.savefig('sigma40_vh.pdf', dpi=300, bbox_inches='tight')

# %%
plt.rcParams.keys()
# Out:
# KeysView(RcParams({'_internal.classic_mode': False,
#           'agg.path.chunksize': 0,
#           'animation.bitrate': -1,
#           'animation.codec': 'h264',
#           'animation.convert_args': ['-layers', 'OptimizePlus'],
#           'animation.convert_path': 'convert',
#           'animation.embed_limit': 20.0,
#           'animation.ffmpeg_args': [],
#           'animation.ffmpeg_path': 'ffmpeg',
#           'animation.frame_format': 'png',
#           'animation.html': 'none',
#           'animation.writer': 'ffmpeg',
#           'axes.autolimit_mode': 'data',
#           'axes.axisbelow': 'line',
#           'axes.edgecolor': 'white',
#           'axes.facecolor': 'white',
#           'axes.formatter.limits': [-5, 6],
#           'axes.formatter.min_exponent': 0,
#           'axes.formatter.offset_threshold': 4,
#           'axes.formatter.use_locale': False,
#           'axes.formatter.use_mathtext': False,
#           'axes.formatter.useoffset': True,
# ...
